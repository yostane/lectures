# %% [markdown]
# # Preparation de l'environnement

# %% [markdown]
# ## Via Jupyter notebook
#
# Installer l'extension `ipython-sql`:
#
# ```bash
# pip install ipython-sql
# ```

# %%
# %load_ext sql
# %sql sqlite:///ma_base.db

# %%
# %%sql
# SELECT *
# FROM utilisateurs
# WHERE age > 30
# Out:
#  * sqlite:///ma_base.db
# (sqlite3.OperationalError) no such table: utilisateurs
# [SQL: SELECT *
# FROM utilisateurs
# WHERE age > 30]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
