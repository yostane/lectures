# %% [markdown]
# # Introduction à Pandas
#
# - Interactive
# - **PY**thon
# - NoteBook

# %%
import pandas as pd # pd est l'alias de pandas

data = {
    "Année": [2024, 2025, 2026, 2027],
    "Diplôme": ["BAC", "B1", "B2", "B3"]
}

df = pd.DataFrame(data)
df
# Out:
#    Année Diplôme
# 0   2024     BAC
# 1   2025      B1
# 2   2026      B2
# 3   2027      B3

# %%
df["Année"].max()
# Out:
# np.int64(2027)

# %% [markdown]
# describe permet de donner des statistiques descriptives sur un DataFrame

# %%
df.describe()
# Out:
#              Année
# count     4.000000
# mean   2025.500000
# std       1.290994
# min    2024.000000
# 25%    2024.750000
# 50%    2025.500000
# 75%    2026.250000
# max    2027.000000

# %%
moyennes = {
    "Année": [2024, 2025, 2026, 2027],
    "Diplôme": ["BAC", "B1", "B2", "B3"],
    "Moyenne": [2, 19.4, 10, 15.8]
}

df_moyennes = pd.DataFrame(moyennes)
df_moyennes
# Out:
#    Année Diplôme  Moyenne
# 0   2024     BAC      2.0
# 1   2025      B1     19.4
# 2   2026      B2     10.0
# 3   2027      B3     15.8

# %%
import matplotlib.pyplot as plt

plt.plot(df_moyennes["Année"], df_moyennes["Moyenne"])
plt.show()

# %%
plt.plot(df_moyennes["Année"], df_moyennes["Moyenne"], marker="o")
plt.title("Moyenne par année")
plt.xlabel("Année")
plt.ylabel("Moyenne")
plt.grid(True)
plt.show()
