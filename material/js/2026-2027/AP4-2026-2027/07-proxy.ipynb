// %% [markdown]
// # Proxy
//
// Permet à d'exécuter une fonction lorsqu'une propriété est modifiée

// %%
const target = {
  message1: "hello",
  message2: "everyone",
};

const handler1 = {
  set(obj, prop, value) {
    console.log(obj, prop, value);
    obj[prop] = value;
    return true;
  }
};

const proxy1 = new Proxy(target, handler1);

proxy1.message1 = "I love";
proxy1.message2 = "Javascript";
