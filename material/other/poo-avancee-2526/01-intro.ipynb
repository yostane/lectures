# %% [markdown]
# # Introduction / rappel de la POO
#
# La Programmation Orientée Objet (POO) est un paradigme (technique) de programmation qui utilise des "objets" pour représenter des données et des comportements. Elle permet de structurer le code de manière plus modulaire et réutilisable.

# %%
from datetime import datetime

class Car:
  def __init__(self, brand, model, release_year) -> None:
    """__init__ s'appelle un constructeur, il est appelé au moment de l'instanciation (création de l'objet).
    Il est utilisé pour initialiser les propriétés (et par convention les définir).
    """
    self.brand = brand
    self.model = model
    self.release_year = release_year
  
  def __eq__(self, other_car: object) -> bool:
    """(eq vient equals) c'est une fonction qui définit l'identité
    -> comment savoir que deux objets voitures sont les mêmes"""
    return type(other_car) is Car and other_car.brand == self.brand \
      and other_car.model == self.model and other_car.release_year == self.release_year
  
  def start(self):
    self.last_start_date = datetime.now()
    print("Vroom vroom")

carA = Car("Peugeot", "206", 1990)
carB = Car("Peugeot", "206", 1990)
carC = Car("Skoda", "Fabia", 2000)
carA.start()
print(carA.last_start_date)
print("carA == carB", carA == carB)
print("carB == carC", carB == carC)
print("carA == carC", carA == carC)
# Out:
# Vroom vroom
# 2025-11-17 15:20:40.624889
# carA == carB True
# carB == carC False
# carA == carC False

# %% [markdown]
# Il est fortement recommandé de typer les variables, fonctions et arguments. `None` est le type spécial pour indiquer qu'une fonction ne retourne rien (équivalent de void en C/C++ et certains autres langages).

# %% [markdown]
# On peut surcharger (redéfinir) des méthodes héritées d'une classe parente dans une classe enfant pour adapter leur comportement. Par exemple, on peut redéfinir la méthode `__str__` pour personnaliser la représentation en chaîne de caractères d'un objet.

# %% [markdown]
# Exemple d'un gagage qui loue des voitures en maintenant deux listes, une pour les voitures disponibles et une pour les voitures louées.

# %%
class Garage:
  def __init__(self, name: str, cars: list[Car]) -> None:
    self.name = name
    # Le parc initial de voitures est disponible
    self.available_cars = cars
    # La list de voitures louées est vide par défaut
    # Ici donc, on initialise la liste à vide et on en profite pour définir son type
    self.rented_cars: list[Car] = []
  
  def rent(self, car_to_rent: Car):
    """Si dispo, on met la voiture dans les listes des voitues à louer"""
    if car_to_rent in self.available_cars:
      self.available_cars.remove(car_to_rent)
      self.rented_cars.append(car_to_rent)
      print("Voiture louée")
    else:
      print("Voiture non disponible (soit déjà louée, soit pas dans le garage)")
    
  def __str__(self) -> str:
    return f"Garage {self.name}. Il y a actuellement {len(self.available_cars)} voiture(s) \
disponibles et {len(self.rented_cars)} voiture(s) en location."

garA = Garage("Chez bibi", [carA, carC])
garA.rent(carA)
garA.rent(carA)
garA.rent(Car("Tutu", "Titi", 2000))
print(garA)
# Out:
# Voiture louée
# Voiture non disponible (soit déjà louée, soit pas dans le garage)
# Voiture non disponible (soit déjà louée, soit pas dans le garage)
# Garage Chez bibi. Il y a actuellement 1 voiture(s) disponibles et 1 voiture(s) en location.

# %% [markdown]
# Bien que très rare en Python, il est possible d'avoir une classe qui hérite de plusieurs classes parentes (héritage multiple).

# %%
class Company:
  def sell_product(self):
    pass

class Building:
  def open_door(self):
    pass

class School (Company, Building):
  def start_class(self):
    self.sell_product()
    self.open_door()

# %% [markdown]
# ## Vérification des types hint
#
# Python ne vérifie pas les types hint à l'exécution. Voici quelques options pour vérifier les types hint :
#   - On peut utiliser les IDE comme PyCharm ou VSCode qui intègrent des vérificateurs de types.
#   - On peut utiliser des outils externes comme `mypy`.
#   - On peut utiliser des bibliothèques comme `pydantic` pour valider les types à l'exécution.

# %% [markdown]
# Voici un exemple de `pydantic` pour valider les types à l'exécution (nécessite d'installer la bibliothèque avec `pip install pydantic`):

# %%
from pydantic import BaseModel

class Weapon(BaseModel):
  name: str
  power: int

class Knight(BaseModel):
  hp: int
  name: str
  gold: int
  weapons: list[Weapon]
  
  def attack(self):
    pass
  
# Ce code génère une erreur de validation au runtime
w = Weapon(name="Hache", power="Toto")  

weapons: list[Weapon] = [
  Weapon(name="Hache", power=100), 
  Weapon(name="Epee", power=50)
  ]
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 14
#      11   weapons: list[Weapon]
#      13 # Ce code génère une erreur de validation au runtime
# ---> 14 w = Weapon(name="Hache", power="Toto")
#      16 weapons: list[Weapon] = [
#      17   Weapon(name="Hache", power=100),
#      18   Weapon(name="Epee", power=50)
#      19   ]
#
# File ~/dev/github/yostane/lectures/material/other/poo-avancee-2526/.venv/lib/python3.13/site-packages/pydantic/main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Weapon
# power
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='Toto', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_parsing
